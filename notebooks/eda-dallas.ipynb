# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import altair as alt
import json

# %%
df = gpd.read_file('../data/master.geojson')
temp = df.copy()
df.sample(3)
# Out:
#         id        name  illiterate  education  employed  unemployed  water  \
# 553  25807    Tibirita        7.30      35.22     16.56        8.49  25.66
# 578  25290  Fusagasugá        3.36      60.39     39.07        4.07   2.21
# 965  73024   Alpujarra        8.21      41.82     36.30        4.01   7.15
#
#      internet    men  women  ...  cases2012  cases2013  cases2014  cases2015  \
# 553     46.68  49.32  50.68  ...          0          0          0          0
# 578     40.15  48.12  51.88  ...         37        108        168        262
# 965     55.41  52.02  47.98  ...         58         28          2          5
#
#      cases2016  cases2017  cases2018  cases2019      area  \
# 553          0          0          0          0  0.004614
# 578       1410         36         11        112  0.015786
# 965          4          0          1          7  0.040807
#
#                                               geometry
# 553  POLYGON ((-73.491 5.129, -73.491 5.127, -73.49...
# 578  POLYGON ((-74.283 4.38, -74.284 4.38, -74.283 ...
# 965  POLYGON ((-74.936 3.482, -74.935 3.482, -74.93...
#
# [3 rows x 38 columns]

# %%
# # shapes
# temp = df.copy()

# # population density
# temp["density2019"] = df["pop2019"] / df["area"]

# (
#     alt.Chart(temp)
#     .mark_geoshape()
#     .encode(
#         tooltip=["name:N", 'pop2019:Q', 'area:Q'],
#         color=alt.Color("density2019:Q", scale=alt.Scale(type="log", scheme="reds"), title='People per km²')
#     )
#     .project(type="mercator")
#     .properties(width=600, height=600, title='Colombia 2019 Population Density')
# )

# %%
# # possibly the unemployment rate
# temp["unemployment_rate"] = temp["unemployed"] / (temp["employed"] + temp["unemployed"])

# (
#     alt.Chart(temp)
#     .mark_geoshape()
#     .encode(
#         tooltip=["name:N", "unemployment_rate:Q"],
#         color=alt.Color("unemployment_rate:Q", scale=alt.Scale(type="log", scheme="blues"))
#     )
#     .project(type="mercator")
#     .properties(width=600, height=600)
# )

# %%
# # this shows the proportion of the population with internet access.
# temp["internet_access_rate"] = temp["internet"] / (temp["men"] + temp["women"])

# (
#     alt.Chart(temp)
#     .mark_geoshape()
#     .encode(
#         tooltip=["name:N", "internet_access_rate:Q"],
#         color=alt.Color("internet_access_rate:Q", scale=alt.Scale(type="log", scheme="greens"))
#     )
#     .project(type="mercator")
#     .properties(width=600, height=600)
# )
