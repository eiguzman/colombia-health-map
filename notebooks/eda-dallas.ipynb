# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import altair as alt
import json

# %%
df = gpd.read_file('../data/master.geojson')
temp = df.copy()
df.sample(3)
# Out:
#         id          name  illiterate  education  employed  unemployed  water  \
# 217  15176  Chiquinquirá        4.46      58.24     39.80        4.37   2.50
# 741  52083         Belén        7.19      44.47     29.49       10.46   8.41
# 256  15325       Guayatá        9.35      35.12     33.80        3.66  13.15
#
#      internet    men  women  ...  cases2012  cases2013  cases2014  cases2015  \
# 217     53.70  47.67  52.33  ...          0          2          0          1
# 741     88.50  48.96  51.04  ...          0          0          0          1
# 256     65.38  50.16  49.84  ...          0          0          0          0
#
#      cases2016  cases2017  cases2018  cases2019      area  \
# 217          0          0          0          0  0.013463
# 741          0          0          0          1  0.003386
# 256          0          0          0          0  0.008152
#
#                                               geometry
# ...

# %%
# # shapes
# temp = df.copy()

# # population density
# temp["density2019"] = df["pop2019"] / df["area"]

# density2019 = (
#     alt.Chart(temp)
#     .mark_geoshape()
#     .encode(
#         tooltip=["name:N", 'pop2019:Q', 'area:Q'],
#         color=alt.Color("density2019:Q", scale=alt.Scale(type="log", scheme="reds"), title='People per km²')
#     )
#     .project(type="mercator")
#     .properties(width=600, height=600, title='Colombia 2019 Population Density')
# )

# density2019.save('../images/population-density-2019.png', scale_factor=2)

# %%
# # possibly the unemployment rate
# temp["unemployment_rate"] = temp["unemployed"] / (temp["employed"] + temp["unemployed"])

# unemployment_rate = (
#     alt.Chart(temp)
#     .mark_geoshape()
#     .encode(
#         tooltip=["name:N", "unemployment_rate:Q"],
#         color=alt.Color("unemployment_rate:Q", scale=alt.Scale(type="log", scheme="blues"), title='Unemployment Rate')
#     )
#     .project(type="mercator")
#     .properties(width=600, height=600, title='Relative Unemployment Rate')
# )

# unemployment_rate.save('../images/relative-unemployment-rate.png', scale_factor=2)

# %%
# # this shows the proportion of the population with internet access.
# temp["internet_access_rate"] = temp["internet"] / (temp["men"] + temp["women"])

# no_intenet = (
#     alt.Chart(temp)
#     .mark_geoshape()
#     .encode(
#         tooltip=["name:N", "internet_access_rate:Q"],
#         color=alt.Color("internet_access_rate:Q", scale=alt.Scale(type="log", scheme="greens"), title='Proportion Without Internet')
#     )
#     .project(type="mercator")
#     .properties(width=600, height=600, title='Proportion of Population Without Internet Access')
# )

# no_intenet.save('../images/proportion-of-population-without-internet-access.png', scale_factor=2)
